# %%
print("Hello World")

# %% [markdown]
# # Python Variable

# %% [markdown]
# - name that points memory location , use to store value

# %% [markdown]
# - Variable name :- variable value

# %% [markdown]
# # rules for creating variable

# %% [markdown]
# - 1) should start with alphabet and underscore
# - 2) white spaces not allowed
# - 3) should not start with number
# - 4) keywords are not allowed

# %% [markdown]
# #  Data Types

# %% [markdown]
# - int :- number
# - Float :- floating point value
# - string :- character

# %%
name = "Ekta"

# %%
name

# %%
print(name)

# %% [markdown]
# # Input value

# %%
input("Enter Your name")

# %%
age = input("Enter Your age")

# %%
print(age)

# %%
age = float(input("Enter your age"))

# %%
print(age+age)

# %%
A = 10
B = 40
print("Addition =" , A + B)
print("Subtraction= " , B - A)
print ("division = ", B/A)
print("Multiplication=" ,A*B)
print("Floor Division=" ,B//A)
print("Exponent" , B**A)

# %% [markdown]
# # Operators

# %% [markdown]
# - Arithmetic Operator

# %%
# +, -, /, *, %, //, **
# % - modulos - remainder
# 10%3=1
# // floor division
# 10/3=3.33333333
# 10//3 = 3
# 5**3 = 125

# %%
print(10/3)

# %%
print(10//3)

# %%
print(10**3)

# %% [markdown]
# - Assigment operator

# %%
# =, +=, -=, /=, *=, %=, //=, **=

# %%
a=10
print(a)

# %%
a+=20
print(a)

# %%
a-=10
print(a)

# %%
a/=10
print(a)

# %% [markdown]
# - Comparison operator

# %%
# True/ False
# ==, <, >, <=, >=, !=

# %%
print(10==10)

# %%
print(10<=10)

# %%
print(10!=10)

# %% [markdown]
# - Logical Operator

# %%
# and, or, not

# %%
a = 10
b = 20

# %%
print(a>40 or a<40)

# %%
print(a>40 and a<40)

# %%
print (not a>40 and a<40)
